# %% [markdown]
# # 例4-6

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
stdata=pd.read_csv('students.csv')

# %%
data = stdata[['Height', 'Weight','Age','Score']]  #准备数据
pd.tools.plotting.scatter_matrix(data,diagonal='kde',c='k')  #绘图
plt.show()
#值得注意的是，课本上的代码有误，应该是pd.tools.plotting
